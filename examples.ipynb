# %%
from rm_scrape import get_house_URLs
from rm_scrape import House
from rm_scrape import search_to_df

# %%
search_URL = "https://www.rightmove.co.uk/property-for-sale/find.html?locationIdentifier=POSTCODE%5E139221&minBedrooms=3&maxPrice=350000&radius=3.0&sortType=1&propertyTypes=detached%2Csemi-detached%2Cterraced&primaryDisplayPropertyType=houses&includeSSTC=false&mustHave=parking%2Cgarden&dontShow=newHome%2Cretirement%2CsharedOwnership&furnishTypes=&keywords="

# %%
get_house_URLs(search_URL)
# Out:
# ['https://www.rightmove.co.uk/properties/86492998',
#  'https://www.rightmove.co.uk/properties/75355321',
#  'https://www.rightmove.co.uk/properties/86582416',
#  'https://www.rightmove.co.uk/properties/82434631',
#  'https://www.rightmove.co.uk/properties/98390651',
#  'https://www.rightmove.co.uk/properties/75924285',
#  'https://www.rightmove.co.uk/properties/87987997',
#  'https://www.rightmove.co.uk/properties/99195383',
#  'https://www.rightmove.co.uk/properties/87908197',
#  'https://www.rightmove.co.uk/properties/84915718',
#  'https://www.rightmove.co.uk/properties/87876988',
#  'https://www.rightmove.co.uk/properties/71297856',
#  'https://www.rightmove.co.uk/properties/99591620']

# %%
house = House("https://www.rightmove.co.uk/properties/86492998#/")

# %%
house.info()
# Out:
# {'URL': 'https://www.rightmove.co.uk/properties/86492998#/',
#  'Street Address': 'Turpyn Court, Cambridge',
#  'Property Type': 'Terraced',
#  'Bedrooms': 3,
#  'Bathrooms': 2,
#  'Size (sq ft)': 'NA',
#  'Guide Price': 310000}

# %%
search_to_df(search_URL)
# Out:
#                                                 URL  \
# 0   https://www.rightmove.co.uk/properties/86492998
# 1   https://www.rightmove.co.uk/properties/75355321
# 2   https://www.rightmove.co.uk/properties/86582416
# 3   https://www.rightmove.co.uk/properties/82434631
# 4   https://www.rightmove.co.uk/properties/98390651
# 5   https://www.rightmove.co.uk/properties/75924285
# 6   https://www.rightmove.co.uk/properties/87987997
# 7   https://www.rightmove.co.uk/properties/99195383
# 8   https://www.rightmove.co.uk/properties/87908197
# 9   https://www.rightmove.co.uk/properties/84915718
# 10  https://www.rightmove.co.uk/properties/87876988
# 11  https://www.rightmove.co.uk/properties/71297856
# 12  https://www.rightmove.co.uk/properties/99591620
#
#                                        Street Address   Property Type  \
# 0                             Turpyn Court, Cambridge        Terraced
# 1         Ross Street, Cambridge, Cambridgeshire, CB1           House
# ...
